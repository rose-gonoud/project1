# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import random
import os

# %%
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

file_to_load1 = os.path.join("Output CSVs", "NYcrime.csv")

# load your city's CSV in a dataframe
NYcrimeDF = pd.read_csv(file_to_load1)

# filter whole NY dataset to just showing rates, not counts:
NYcrimeRates = NYcrimeDF.loc[NYcrimeDF["variable"] == "rate"]

# creating violent crime only set from there:
# restrict this violent crime set to a period of years useful for comparison w/ weed-legal cities:
NYcrimeRatesYears = NYcrimeRates.loc[NYcrimeRates["year"].isin(years)]
NYcrimeRatesYears = NYcrimeRatesYears.drop_duplicates()
# remove extraneous columns
NYcrimeRatesYears = NYcrimeRatesYears.drop(columns=["key", "id", "place_name"])
# sort the years to print in ascending order
NYcrimeRatesYears = NYcrimeRatesYears.sort_values(['year'], ascending=[True])

# create a list with the text of each violent-crime category and filter data again
Vcrime = ["Forcible rape", "Murder and nonnegligent manslaughter", "Aggravated assault", "Rape (revised definition)"]
NYcrimeRatesViolent = NYcrimeRatesYears.loc[NYcrimeRatesYears["crime_type"].isin(Vcrime)]

# Create seperate dataframes for each type of crime:

# create another category for the rape-specific crime types
rapeCategories = ["Forcible rape", "Rape (revised definition)"]
NYrape = NYcrimeRatesViolent.loc[NYcrimeRatesViolent["crime_type"].isin(rapeCategories)]
# set the index of each dataframe to the year the data was from
NYrape = NYrape.set_index(["year"])

NYmurder = NYcrimeRatesViolent.loc[NYcrimeRatesViolent["crime_type"] == "Murder and nonnegligent manslaughter"]
NYmurder = NYmurder.set_index(["year"])

NYassault = NYcrimeRatesViolent.loc[NYcrimeRatesViolent["crime_type"] == "Aggravated assault"]
NYassault = NYassault.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
NY_x_axis = NYrape.index
# each bar is a line here
p1 = plt.bar(NY_x_axis, NYrape["value"], color='black', alpha=0.5, align="center")
# the bottom arguments indicate where to start the second, third, etc bar in the set. From 2 on they become sums:
p2 = plt.bar(NY_x_axis, NYmurder["value"].values, color='#AD1457', bottom=NYrape["value"].values)
p3 = plt.bar(NY_x_axis, NYassault["value"].values, color='#4527A0', bottom=(NYmurder["value"] + NYrape["value"]).values)

tick_locations = [value for value in NY_x_axis]
plt.xticks(tick_locations, years)
plt.title("New York, NY Violent Crime Rate: \n Comp Over Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0]), ("Rape", "Murder & Non-negligent Manslaughter", "Aggravated Assault"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
NYcrimeRatesViolent
# Out:
#                    name   type variable       value  year  \
# 105  New York, New York  place     rate  314.930281  2009
# 39   New York, New York  place     rate    5.606537  2009
# 122  New York, New York  place     rate    9.903693  2009
# 129  New York, New York  place     rate   12.428020  2010
# 83   New York, New York  place     rate  327.603088  2010
# 52   New York, New York  place     rate    6.429941  2010
# 138  New York, New York  place     rate   13.297816  2011
# 145  New York, New York  place     rate  363.242256  2011
# 6    New York, New York  place     rate    6.271406  2011
# 148  New York, New York  place     rate    5.054639  2012
# 41   New York, New York  place     rate   14.017877  2012
# 71   New York, New York  place     rate  376.516316  2012
# 157  New York, New York  place     rate   13.244203  2013
# 170  New York, New York  place     rate  378.353064  2013
# 239  New York, New York  place     rate    3.989935  2013
# 240  New York, New York  place     rate    3.929696  2014
# 45   New York, New York  place     rate   25.843946  2014
# 9    New York, New York  place     rate  371.255962  2014
# 226  New York, New York  place     rate    4.116545  2015
# 183  New York, New York  place     rate   26.242971  2015
# 200  New York, New York  place     rate  357.227185  2015
# 229  New York, New York  place     rate   27.687907  2016
# 180  New York, New York  place     rate  360.374683  2016
# 235  New York, New York  place     rate    3.910392  2016
#
#                                crime_type
# 105                    Aggravated assault
# 39   Murder and nonnegligent manslaughter
# 122                         Forcible rape
# 129                         Forcible rape
# 83                     Aggravated assault
# 52   Murder and nonnegligent manslaughter
# 138                         Forcible rape
# 145                    Aggravated assault
# 6    Murder and nonnegligent manslaughter
# 148  Murder and nonnegligent manslaughter
# 41                          Forcible rape
# 71                     Aggravated assault
# 157             Rape (revised definition)
# 170                    Aggravated assault
# 239  Murder and nonnegligent manslaughter
# 240  Murder and nonnegligent manslaughter
# 45              Rape (revised definition)
# 9                      Aggravated assault
# 226  Murder and nonnegligent manslaughter
# 183             Rape (revised definition)
# 200                    Aggravated assault
# 229             Rape (revised definition)
# 180                    Aggravated assault
# 235  Murder and nonnegligent manslaughter

# %%
# Non-violent crime categorization for NY starts here:
# create non-violent crimes list
nonVcrime = ["Motor vehicle theft", "Larceny", "Burglary", "Robbery", "Property crime"]

# restricting new DataFrame to non-violent crimes in above list:
NYcrimeRatesNonViolent = NYcrimeRates.loc[NYcrimeRates["crime_type"].isin(nonVcrime)]
NYcrimeRatesNonViolent = NYcrimeRatesNonViolent.drop_duplicates()
NYcrimeRatesNonViolentYears = NYcrimeRatesNonViolent.loc[NYcrimeRatesNonViolent["year"].isin(years)]

# drop extraneous columns
NYcrimeRatesNVComparison = NYcrimeRatesNonViolentYears.drop(columns=["key", "id", "place_name"])
# sort year in ascending order
NYcrimeRatesNVComparison = NYcrimeRatesNVComparison.sort_values(['year'], ascending=[True])

# Create seperate dataframes for each type of crime:
NYlarceny = NYcrimeRatesNVComparison.loc[NYcrimeRatesNVComparison["crime_type"] == "Larceny"]
# set the index of each dataframe to the year
NYlarceny = NYlarceny.set_index(["year"])

NYmotor = NYcrimeRatesNVComparison.loc[NYcrimeRatesNVComparison["crime_type"] == "Motor vehicle theft"]
NYmotor = NYmotor.set_index(["year"])

NYburglary = NYcrimeRatesNVComparison.loc[NYcrimeRatesNVComparison["crime_type"] == "Burglary"]
NYburglary = NYburglary.set_index(["year"])

NYrobbery = NYcrimeRatesNVComparison.loc[NYcrimeRatesNVComparison["crime_type"] == "Robbery"]
NYrobbery = NYrobbery.set_index(["year"])

NYpropCrime = NYcrimeRatesNVComparison.loc[NYcrimeRatesNVComparison["crime_type"] == "Property crime"]
NYpropCrime = NYpropCrime.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
NY_x_axis = NYlarceny.index
# each bar is a line here
p1 = plt.bar(NY_x_axis, NYlarceny["value"], color='purple', alpha=0.5, align="center")
p2 = plt.bar(NY_x_axis, NYmotor["value"].values, color='red', bottom=NYlarceny["value"].values)
p3 = plt.bar(NY_x_axis, NYburglary["value"].values, color='black', bottom=(NYmotor["value"] + NYlarceny["value"]).values)
p4 = plt.bar(NY_x_axis, NYrobbery["value"].values, color="#ADD8E6", bottom = (NYmotor["value"] + NYlarceny["value"] + NYburglary["value"]).values)
p5 = plt.bar(NY_x_axis, NYpropCrime["value"].values, color='pink', bottom = (NYmotor["value"] + NYlarceny["value"] + NYburglary["value"] + NYrobbery["value"]).values)

tick_locations = [value for value in NY_x_axis]
plt.xticks(tick_locations, years)
plt.title("New York, NY Non-Violent Crime Rate: \n Comp Over Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ("Larceny", "Motor-vehicle Theft", "Burglary", "Robbery", "Property Crime"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
NYcrimeRatesNVComparison
# Out:
#                    name   type variable        value  year  \
# 3    New York, New York  place     rate  1339.450609  2009
# 119  New York, New York  place     rate  1690.293679  2009
# 16   New York, New York  place     rate   223.547291  2009
# 27   New York, New York  place     rate   221.368955  2009
# 150  New York, New York  place     rate   127.295779  2009
# 93   New York, New York  place     rate  1336.012155  2010
# 40   New York, New York  place     rate   235.220673  2010
# 84   New York, New York  place     rate   215.043135  2010
# 108  New York, New York  place     rate  1674.843648  2010
# 68   New York, New York  place     rate   123.788358  2010
# 100  New York, New York  place     rate  1710.413273  2011
# 128  New York, New York  place     rate   240.785448  2011
# 65   New York, New York  place     rate   221.130984  2011
# 177  New York, New York  place     rate   114.882411  2011
# 117  New York, New York  place     rate  1374.399878  2011
# 73   New York, New York  place     rate    98.800699  2012
# 85   New York, New York  place     rate  1722.196319  2012
# 50   New York, New York  place     rate   224.804766  2012
# 155  New York, New York  place     rate   243.696328  2012
# 66   New York, New York  place     rate  1398.590854  2012
# 131  New York, New York  place     rate   197.781691  2013
# 151  New York, New York  place     rate  1690.910784  2013
# 104  New York, New York  place     rate   228.319585  2013
# 92   New York, New York  place     rate  1404.588259  2013
# 59   New York, New York  place     rate    88.540834  2013
# 63   New York, New York  place     rate   187.822946  2014
# 134  New York, New York  place     rate  1322.962240  2014
# 37   New York, New York  place     rate  1601.935251  2014
# 35   New York, New York  place     rate   195.670537  2014
# 14   New York, New York  place     rate    91.150065  2014
# 213  New York, New York  place     rate  1518.677476  2015
# 193  New York, New York  place     rate    86.377267  2015
# 189  New York, New York  place     rate   164.872286  2015
# 185  New York, New York  place     rate   198.178873  2015
# 230  New York, New York  place     rate  1267.427923  2015
# 202  New York, New York  place     rate    74.344131  2016
# 211  New York, New York  place     rate   140.552313  2016
# 222  New York, New York  place     rate  1247.449929  2016
# 228  New York, New York  place     rate  1462.346373  2016
# 233  New York, New York  place     rate   181.442169  2016
#
#               crime_type
# 3                Larceny
# 119       Property crime
# 16              Burglary
# 27               Robbery
# 150  Motor vehicle theft
# 93               Larceny
# 40               Robbery
# 84              Burglary
# 108       Property crime
# 68   Motor vehicle theft
# 100       Property crime
# 128              Robbery
# 65              Burglary
# 177  Motor vehicle theft
# 117              Larceny
# 73   Motor vehicle theft
# 85        Property crime
# 50              Burglary
# 155              Robbery
# 66               Larceny
# 131             Burglary
# 151       Property crime
# 104              Robbery
# 92               Larceny
# 59   Motor vehicle theft
# 63              Burglary
# 134              Larceny
# 37        Property crime
# 35               Robbery
# 14   Motor vehicle theft
# 213       Property crime
# 193  Motor vehicle theft
# 189             Burglary
# 185              Robbery
# 230              Larceny
# 202  Motor vehicle theft
# 211             Burglary
# 222              Larceny
# 228       Property crime
# 233              Robbery

# %%
# created a series object with all-together sums of non-violent crime for NY, in case it's needed:
NYcrimeRatesNVComparison_gb = NYcrimeRatesNVComparison.groupby("year")
summedNV_NYcrime = NYcrimeRatesNVComparison_gb["value"].sum()
summedNV_NYcrime
# Out:
# year
# 2009    3601.956313
# 2010    3584.907969
# 2011    3661.611995
# 2012    3688.088966
# 2013    3610.141153
# 2014    3399.541040
# 2015    3235.533825
# 2016    3106.134914
# Name: value, dtype: float64

# %%
# basic violent crime CO dataset exploration
file_to_load2 = os.path.join("Output CSVs", "COcrime.csv")

COcrimeDF = pd.read_csv(file_to_load2)

COcrimeRates = COcrimeDF.loc[COcrimeDF["variable"] == "rate"]

COcrimeRatesViolent = COcrimeRates.loc[COcrimeRates["crime_type"] == "Violent crime"]
COcrimeRatesViolent = COcrimeRatesViolent.drop_duplicates()
COcrimeRatesViolentYears = COcrimeRatesViolent.loc[COcrimeRatesViolent["year"].isin(years)]

COcrimePostLegalization = COcrimeRatesViolent.loc[COcrimeRatesViolent["year"].isin(years)]
COcrimePostLegalization = COcrimePostLegalization.drop(columns=["key", "id", "place_name"])
COcrimePostLegalization = COcrimePostLegalization.sort_values(['year'], ascending=[True])
COcrimePostLegalization

CO_x_axis = np.arange(len(COcrimePostLegalization["value"]))
postLegalCO = plt.bar(CO_x_axis, COcrimePostLegalization["value"], color='purple', alpha=0.5, align="center")
postLegalCO[4].set_color('g')
postLegalCO[5].set_color('g')
postLegalCO[6].set_color('g')
postLegalCO[7].set_color('g')

tick_locations = [value for value in CO_x_axis]
plt.xticks(tick_locations, years)
plt.title("Colorado Springs, CO Crime Rate: \n Pre- and Post-Marijuana Legalization")
plt.ylabel("Crime Rate (per 100,000 People)")
COcrimePostLegalization
# Out:
#                            name   type variable       value  year  \
# 126  Colorado Springs, Colorado  place     rate  490.008117  2009
# 54   Colorado Springs, Colorado  place     rate  491.849424  2010
# 59   Colorado Springs, Colorado  place     rate  440.190710  2011
# 164  Colorado Springs, Colorado  place     rate  455.253107  2012
# 6    Colorado Springs, Colorado  place     rate  434.066791  2013
# 62   Colorado Springs, Colorado  place     rate  458.254766  2014
# 249  Colorado Springs, Colorado  place     rate  438.319224  2015
# 213  Colorado Springs, Colorado  place     rate  495.784432  2016
#
#         crime_type
# 126  Violent crime
# 54   Violent crime
# 59   Violent crime
# 164  Violent crime
# 6    Violent crime
# 62   Violent crime
# 249  Violent crime
# 213  Violent crime

# %% [markdown]
# Weed legalized in CA and OR all of 2017 and 2018. Weed legalized in CO all of 2013 onwards.
#
# Bar graphs clustered by city showing one bar per year in ascending order, bar height reflecting rate per 100,000ppl.

# %%
COcrimeRates
# creating violent crime only set from there:
# restrict this violent crime set to a period of years useful for comparison w/ weed-legal cities:
COcrimeRatesYears = COcrimeRates.loc[COcrimeRates["year"].isin(years)]
COcrimeRatesYears = COcrimeRatesYears.drop_duplicates()
# remove extraneous columns
COcrimeRatesYears = COcrimeRatesYears.drop(columns=["key", "id", "place_name"])
# sort the years to print in ascending order
COcrimeRatesYears = COcrimeRatesYears.sort_values(['year'], ascending=[True])

# create a list with the text of each violent-crime category and filter data again
Vcrime = ["Forcible rape", "Murder and nonnegligent manslaughter", "Aggravated assault", "Rape (revised definition)", 'Rape (legacy definition)']
COcrimeRatesViolent = COcrimeRatesYears.loc[COcrimeRatesYears["crime_type"].isin(Vcrime)]

# Create seperate dataframes for each type of crime:

# create another category for the rape-specific crime types
rapeCategories = ["Forcible rape", "Rape (revised definition)"]
COrape = COcrimeRatesViolent.loc[COcrimeRatesViolent["crime_type"].isin(rapeCategories)]
# set the index of each dataframe to the year the data was from
COrape = COrape.set_index(["year"])

COmurder = COcrimeRatesViolent.loc[COcrimeRatesViolent["crime_type"] == "Murder and nonnegligent manslaughter"]
COmurder = COmurder.set_index(["year"])

COassault = COcrimeRatesViolent.loc[COcrimeRatesViolent["crime_type"] == "Aggravated assault"]
COassault = COassault.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
CO_x_axis = COrape.index
# each bar is a line here
p1 = plt.bar(CO_x_axis, COrape["value"], color='black', alpha=0.5, align="center")
# the bottom arguments indicate where to start the second, third, etc bar in the set. From 2 on they become sums:
p2 = plt.bar(CO_x_axis, COmurder["value"].values, color='#AD1457', bottom=COrape["value"].values)
p3 = plt.bar(CO_x_axis, COassault["value"].values, color='#4527A0', bottom=(COmurder["value"] + COrape["value"]).values)

tick_locations = [value for value in CO_x_axis]
plt.xticks(tick_locations, years)
plt.title("Colorado Springs, CO Violent Crime Rate: \n Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0]), ("Rape", "Murder & Non-negligent Manslaughter", "Aggravated Assault"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
COcrimeRatesViolent
# Out:
#                            name   type variable       value  year  \
# 44   Colorado Springs, Colorado  place     rate    3.734818  2009
# 34   Colorado Springs, Colorado  place     rate  269.902845  2009
# 7    Colorado Springs, Colorado  place     rate   85.651825  2009
# 263  Colorado Springs, Colorado  place     rate    5.026565  2010
# 35   Colorado Springs, Colorado  place     rate   80.173718  2010
# 122  Colorado Springs, Colorado  place     rate  274.450471  2010
# 119  Colorado Springs, Colorado  place     rate   75.292674  2011
# 113  Colorado Springs, Colorado  place     rate    6.136707  2011
# 31   Colorado Springs, Colorado  place     rate  252.785121  2011
# 110  Colorado Springs, Colorado  place     rate   82.815352  2012
# 109  Colorado Springs, Colorado  place     rate  247.289417  2012
# 37   Colorado Springs, Colorado  place     rate    4.163900  2012
# 192  Colorado Springs, Colorado  place     rate  247.415778  2013
# 264  Colorado Springs, Colorado  place     rate    5.961826  2013
# 45   Colorado Springs, Colorado  place     rate   84.841370  2013
# 91   Colorado Springs, Colorado  place     rate    0.000000  2013
# 127  Colorado Springs, Colorado  place     rate  270.368065  2014
# 167  Colorado Springs, Colorado  place     rate    4.494897  2014
# 26   Colorado Springs, Colorado  place     rate   92.594882  2014
# 245  Colorado Springs, Colorado  place     rate  274.308702  2015
# 216  Colorado Springs, Colorado  place     rate    5.525961  2015
# 206  Colorado Springs, Colorado  place     rate   75.374108  2015
# 233  Colorado Springs, Colorado  place     rate    5.171154  2016
# 200  Colorado Springs, Colorado  place     rate   96.097287  2016
# 254  Colorado Springs, Colorado  place     rate  300.357887  2016
#
#                                crime_type
# 44   Murder and nonnegligent manslaughter
# 34                     Aggravated assault
# 7                           Forcible rape
# 263  Murder and nonnegligent manslaughter
# 35                          Forcible rape
# 122                    Aggravated assault
# 119                         Forcible rape
# 113  Murder and nonnegligent manslaughter
# 31                     Aggravated assault
# 110                         Forcible rape
# 109                    Aggravated assault
# 37   Murder and nonnegligent manslaughter
# 192                    Aggravated assault
# 264  Murder and nonnegligent manslaughter
# 45              Rape (revised definition)
# 91               Rape (legacy definition)
# 127                    Aggravated assault
# 167  Murder and nonnegligent manslaughter
# 26              Rape (revised definition)
# 245                    Aggravated assault
# 216  Murder and nonnegligent manslaughter
# 206             Rape (revised definition)
# 233  Murder and nonnegligent manslaughter
# 200             Rape (revised definition)
# 254                    Aggravated assault

# %%
# Non-violent crime categorization for NY starts here:
# create non-violent crimes list
nonVcrime = ["Motor vehicle theft", "Larceny", "Burglary", "Robbery", "Property crime"]

# restricting new DataFrame to non-violent crimes in above list:
COcrimeRatesNonViolent = COcrimeRates.loc[COcrimeRates["crime_type"].isin(nonVcrime)]
COcrimeRatesNonViolent = COcrimeRatesNonViolent.drop_duplicates()
COcrimeRatesNonViolentYears = COcrimeRatesNonViolent.loc[COcrimeRatesNonViolent["year"].isin(years)]

# drop extraneous columns
COcrimeRatesNVComparison = COcrimeRatesNonViolentYears.drop(columns=["key", "id", "place_name"])
# sort year in ascending order
COcrimeRatesNVComparison = COcrimeRatesNVComparison.sort_values(['year'], ascending=[True])

# Create seperate dataframes for each type of crime:
COlarceny = COcrimeRatesNVComparison.loc[COcrimeRatesNVComparison["crime_type"] == "Larceny"]
# set the index of each dataframe to the year
COlarceny = COlarceny.set_index(["year"])

COmotor = COcrimeRatesNVComparison.loc[COcrimeRatesNVComparison["crime_type"] == "Motor vehicle theft"]
COmotor = COmotor.set_index(["year"])

COburglary = COcrimeRatesNVComparison.loc[COcrimeRatesNVComparison["crime_type"] == "Burglary"]
COburglary = COburglary.set_index(["year"])

COrobbery = COcrimeRatesNVComparison.loc[COcrimeRatesNVComparison["crime_type"] == "Robbery"]
COrobbery = COrobbery.set_index(["year"])

COpropCrime = COcrimeRatesNVComparison.loc[COcrimeRatesNVComparison["crime_type"] == "Property crime"]
COpropCrime = COpropCrime.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
CO_x_axis = COlarceny.index
# each bar is a line here
p1 = plt.bar(CO_x_axis, COlarceny["value"], color='purple', alpha=0.5, align="center")
p2 = plt.bar(CO_x_axis, COmotor["value"].values, color='red', bottom=COlarceny["value"].values)
p3 = plt.bar(CO_x_axis, COburglary["value"].values, color='black', bottom=(COmotor["value"] + COlarceny["value"]).values)
p4 = plt.bar(CO_x_axis, COrobbery["value"].values, color="#ADD8E6", bottom = (COmotor["value"] + COlarceny["value"] + COburglary["value"]).values)
p5 = plt.bar(CO_x_axis, COpropCrime["value"].values, color='pink', bottom = (COmotor["value"] + COlarceny["value"] + COburglary["value"] + COrobbery["value"]).values)

tick_locations = [value for value in NY_x_axis]
plt.xticks(tick_locations, years)
plt.title("Colorado Springs, CO Non-Violent Crime Rate: \n Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ("Larceny", "Motor-vehicle Theft", "Burglary", "Robbery", "Property Crime"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
COcrimeRatesNVComparison
# Out:
#                            name   type variable        value  year  \
# 21   Colorado Springs, Colorado  place     rate   130.718629  2009
# 176  Colorado Springs, Colorado  place     rate   822.904892  2009
# 147  Colorado Springs, Colorado  place     rate  3665.848327  2009
# 82   Colorado Springs, Colorado  place     rate   264.176124  2009
# 92   Colorado Springs, Colorado  place     rate  2578.767311  2009
# 65   Colorado Springs, Colorado  place     rate   323.710812  2010
# 50   Colorado Springs, Colorado  place     rate  3029.510965  2010
# 69   Colorado Springs, Colorado  place     rate  4220.806965  2010
# 75   Colorado Springs, Colorado  place     rate   867.585188  2010
# 104  Colorado Springs, Colorado  place     rate   132.198670  2010
# 193  Colorado Springs, Colorado  place     rate  2684.809290  2011
# 22   Colorado Springs, Colorado  place     rate   105.976208  2011
# 38   Colorado Springs, Colorado  place     rate  3744.807402  2011
# 177  Colorado Springs, Colorado  place     rate   784.318353  2011
# 173  Colorado Springs, Colorado  place     rate   275.679758  2011
# 2    Colorado Springs, Colorado  place     rate   416.852693  2012
# 155  Colorado Springs, Colorado  place     rate   842.264514  2012
# 140  Colorado Springs, Colorado  place     rate   120.984439  2012
# 144  Colorado Springs, Colorado  place     rate  4140.536264  2012
# 56   Colorado Springs, Colorado  place     rate  2881.419057  2012
# 5    Colorado Springs, Colorado  place     rate   442.092326  2013
# 149  Colorado Springs, Colorado  place     rate  2871.077806  2013
# 153  Colorado Springs, Colorado  place     rate    95.847818  2013
# 154  Colorado Springs, Colorado  place     rate   854.375522  2013
# 48   Colorado Springs, Colorado  place     rate  4167.545654  2013
# 129  Colorado Springs, Colorado  place     rate  3667.611344  2014
# 103  Colorado Springs, Colorado  place     rate   369.930037  2014
# 101  Colorado Springs, Colorado  place     rate   620.071064  2014
# 191  Colorado Springs, Colorado  place     rate    90.796923  2014
# 132  Colorado Springs, Colorado  place     rate  2677.610243  2014
# 235  Colorado Springs, Colorado  place     rate    83.110453  2015
# 231  Colorado Springs, Colorado  place     rate   381.733383  2015
# 222  Colorado Springs, Colorado  place     rate   533.586791  2015
# 258  Colorado Springs, Colorado  place     rate  3648.018390  2015
# 214  Colorado Springs, Colorado  place     rate  2732.698216  2015
# 203  Colorado Springs, Colorado  place     rate    94.158104  2016
# 196  Colorado Springs, Colorado  place     rate  3560.770761  2016
# 251  Colorado Springs, Colorado  place     rate   576.799185  2016
# 255  Colorado Springs, Colorado  place     rate   446.658465  2016
# 257  Colorado Springs, Colorado  place     rate  2537.313111  2016
#
#               crime_type
# 21               Robbery
# 176             Burglary
# 147       Property crime
# 82   Motor vehicle theft
# 92               Larceny
# 65   Motor vehicle theft
# 50               Larceny
# 69        Property crime
# 75              Burglary
# 104              Robbery
# 193              Larceny
# 22               Robbery
# 38        Property crime
# 177             Burglary
# 173  Motor vehicle theft
# 2    Motor vehicle theft
# 155             Burglary
# 140              Robbery
# 144       Property crime
# 56               Larceny
# 5    Motor vehicle theft
# 149              Larceny
# 153              Robbery
# 154             Burglary
# 48        Property crime
# 129       Property crime
# 103  Motor vehicle theft
# 101             Burglary
# 191              Robbery
# 132              Larceny
# 235              Robbery
# 231  Motor vehicle theft
# 222             Burglary
# 258       Property crime
# 214              Larceny
# 203              Robbery
# 196       Property crime
# 251             Burglary
# 255  Motor vehicle theft
# 257              Larceny

# %%
# file_to_load3 = os.path.join("Output CSVs", "Fortworth.csv")

# TXcrimeDF = pd.read_csv(file_to_load3)

# TXcrimeRates = TXcrimeDF.loc[TXcrimeDF["variable"] == "rate"]

# TXcrimeRatesViolent = TXcrimeRates.loc[TXcrimeRates["crime_type"] == "Violent crime"]
# TXcrimeRatesViolent = TXcrimeRatesViolent.drop_duplicates()
# TXcrimeRatesViolentYears = TXcrimeRatesViolent.loc[TXcrimeRatesViolent["year"].isin(years)]
# TXcrimeRatesViolentYears
# Out:
#                                              key                id  \
# 17   1600000US4827000--2009--Violent crime--rate  1600000US4827000
# 49   1600000US4827000--2013--Violent crime--rate  1600000US4827000
# 64   1600000US4827000--2012--Violent crime--rate  1600000US4827000
# 68   1600000US4827000--2011--Violent crime--rate  1600000US4827000
# 75   1600000US4827000--2010--Violent crime--rate  1600000US4827000
# 194  1600000US4827000--2016--Violent crime--rate  1600000US4827000
# 240  1600000US4827000--2015--Violent crime--rate  1600000US4827000
# 255  1600000US4827000--2017--Violent crime--rate  1600000US4827000
# 267  1600000US4827000--2018--Violent crime--rate  1600000US4827000
#
#                   name   type variable       value  year     crime_type  \
# 17   Fort Worth, Texas  place     rate  584.969922  2009  Violent crime
# 49   Fort Worth, Texas  place     rate  560.177939  2013  Violent crime
# 64   Fort Worth, Texas  place     rate  587.455412  2012  Violent crime
# 68   Fort Worth, Texas  place     rate  603.723822  2011  Violent crime
# 75   Fort Worth, Texas  place     rate  575.135344  2010  Violent crime
# 194  Fort Worth, Texas  place     rate  526.266979  2016  Violent crime
# 240  Fort Worth, Texas  place     rate  525.350987  2015  Violent crime
# 255  Fort Worth, Texas  place     rate  560.207727  2017  Violent crime
# 267  Fort Worth, Texas  place     rate  501.479151  2018  Violent crime
#
#          place_name
# 17   Fort Worth, TX
# 49   Fort Worth, TX
# 64   Fort Worth, TX
# 68   Fort Worth, TX
# 75   Fort Worth, TX
# 194  Fort Worth, TX
# 240  Fort Worth, TX
# 255  Fort Worth, TX
# 267  Fort Worth, TX

# %%
# basic CA graphs from an earlier stage of analysis

file_to_load4 = os.path.join("Output CSVs", "Riverside.csv")

CAcrimeDF = pd.read_csv(file_to_load4)

CAcrimeRates = CAcrimeDF.loc[CAcrimeDF["variable"] == "rate"]

CAcrimeRatesViolent = CAcrimeRates.loc[CAcrimeRates["crime_type"] == "Violent crime"]
CAcrimeRatesViolent = CAcrimeRatesViolent.drop_duplicates()
CAcrimeRatesViolentYears = CAcrimeRatesViolent.loc[CAcrimeRatesViolent["year"].isin(years)]
CAcrimeRatesViolentYears

#CA_prepost_legalization = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

CAcrimePostLegalization = CAcrimeRatesViolent.loc[CAcrimeRatesViolent["year"].isin(years)]
CAcrimePostLegalization = CAcrimePostLegalization.drop(columns=["key", "id", "place_name"])
CAcrimePostLegalization = CAcrimePostLegalization.sort_values(['year'], ascending=[True])
CAcrimePostLegalization

CA_x_axis = np.arange(len(CAcrimePostLegalization["value"]))
postLegalCA = plt.bar(CA_x_axis, CAcrimePostLegalization["value"], color='purple', alpha=0.5, align="center")
postLegalCA[8].set_color('g')
postLegalCA[9].set_color('g')

tick_locations = [value for value in CA_x_axis]
plt.xticks(tick_locations, years)
plt.title("Riverside, CA Crime Rate: \n Pre- and Post-Marijuana Legalization")
plt.ylabel("Crime Rate (per 100,000 People)")
CAcrimePostLegalization
# Out:
#                       name   type variable       value  year     crime_type
# 122  Riverside, California  place     rate  511.886778  2009  Violent crime
# 125  Riverside, California  place     rate  479.694162  2010  Violent crime
# 54   Riverside, California  place     rate  426.095244  2011  Violent crime
# 25   Riverside, California  place     rate  443.016981  2012  Violent crime
# 43   Riverside, California  place     rate  420.323428  2013  Violent crime
# 110  Riverside, California  place     rate  433.240571  2014  Violent crime
# 258  Riverside, California  place     rate  446.041651  2015  Violent crime
# 215  Riverside, California  place     rate  529.003118  2016  Violent crime
# 268  Riverside, California  place     rate  508.805785  2017  Violent crime
# 289  Riverside, California  place     rate  509.331706  2018  Violent crime

# %%
# creating violent crime only set from there:
# restrict this violent crime set to a period of years useful for comparison w/ weed-legal cities:
CAcrimeRatesYears = CAcrimeRates.loc[CAcrimeRates["year"].isin(years)]
CAcrimeRatesYears = CAcrimeRatesYears.drop_duplicates()
# remove extraneous columns
CAcrimeRatesYears = CAcrimeRatesYears.drop(columns=["key", "id", "place_name"])
# sort the years to print in ascending order
CAcrimeRatesYears = CAcrimeRatesYears.sort_values(['year'], ascending=[True])

# create a list with the text of each violent-crime category and filter data again
Vcrime = ["Forcible rape", "Murder and nonnegligent manslaughter", "Aggravated assault", "Rape (revised definition)", 'Rape (legacy definition)']
CAcrimeRatesViolent = CAcrimeRatesYears.loc[CAcrimeRatesYears["crime_type"].isin(Vcrime)]

# Create seperate dataframes for each type of crime:

# create another category for the rape-specific crime types
rapeCategories = ["Forcible rape", "Rape (revised definition)"]
CArape = CAcrimeRatesViolent.loc[CAcrimeRatesViolent["crime_type"].isin(rapeCategories)]
# set the index of each dataframe to the year the data was from
CArape = CArape.set_index(["year"])

CAmurder = CAcrimeRatesViolent.loc[CAcrimeRatesViolent["crime_type"] == "Murder and nonnegligent manslaughter"]
CAmurder = CAmurder.set_index(["year"])

CAassault = CAcrimeRatesViolent.loc[CAcrimeRatesViolent["crime_type"] == "Aggravated assault"]
CAassault = CAassault.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
CA_x_axis = CArape.index
# each bar is a line here
p1 = plt.bar(CA_x_axis, CArape["value"], color='black', alpha=0.5, align="center")
# the bottom arguments indicate where to start the second, third, etc bar in the set. From 2 on they become sums:
p2 = plt.bar(CA_x_axis, CAmurder["value"].values, color='#AD1457', bottom=CArape["value"].values)
p3 = plt.bar(CA_x_axis, CAassault["value"].values, color='#4527A0', bottom=(CAmurder["value"] + CArape["value"]).values)

tick_locations = [value for value in CA_x_axis]
plt.xticks(tick_locations, years)
plt.title("Riverside, CA Violent Crime Rate: \n Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0]), ("Rape", "Murder & Non-negligent Manslaughter", "Aggravated Assault"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
CAcrimeRatesViolent
# Out:
#                       name   type variable       value  year  \
# 166  Riverside, California  place     rate   32.680719  2009
# 80   Riverside, California  place     rate  251.774930  2009
# 167  Riverside, California  place     rate    5.002151  2009
# 140  Riverside, California  place     rate  284.569948  2010
# 58   Riverside, California  place     rate   25.839879  2010
# 260  Riverside, California  place     rate    2.981524  2010
# 187  Riverside, California  place     rate    4.228426  2011
# 179  Riverside, California  place     rate  254.356092  2011
# 65   Riverside, California  place     rate   18.540022  2011
# 126  Riverside, California  place     rate   24.239950  2012
# 171  Riverside, California  place     rate  248.778434  2012
# 265  Riverside, California  place     rate    5.103147  2012
# 13   Riverside, California  place     rate  236.076391  2013
# 261  Riverside, California  place     rate    3.160327  2013
# 152  Riverside, California  place     rate   24.650547  2013
# 133  Riverside, California  place     rate    0.000000  2013
# 262  Riverside, California  place     rate    3.756421  2014
# 190  Riverside, California  place     rate  246.671654  2014
# 5    Riverside, California  place     rate   44.764018  2014
# 211  Riverside, California  place     rate  239.581012  2015
# 263  Riverside, California  place     rate    3.095362  2015
# 238  Riverside, California  place     rate   42.406458  2015
# 240  Riverside, California  place     rate    3.068464  2016
# 221  Riverside, California  place     rate  302.857353  2016
# 210  Riverside, California  place     rate   43.265336  2016
# 279  Riverside, California  place     rate    3.658280  2017
# 273  Riverside, California  place     rate  288.699268  2017
# 266  Riverside, California  place     rate   50.606207  2017
# 307  Riverside, California  place     rate  295.750736  2018
# 291  Riverside, California  place     rate    4.229326  2018
# 295  Riverside, California  place     rate   45.314209  2018
#
#                                crime_type
# 166                         Forcible rape
# 80                     Aggravated assault
# 167  Murder and nonnegligent manslaughter
# 140                    Aggravated assault
# 58                          Forcible rape
# 260  Murder and nonnegligent manslaughter
# 187  Murder and nonnegligent manslaughter
# 179                    Aggravated assault
# 65                          Forcible rape
# 126                         Forcible rape
# 171                    Aggravated assault
# 265  Murder and nonnegligent manslaughter
# 13                     Aggravated assault
# 261  Murder and nonnegligent manslaughter
# 152              Rape (legacy definition)
# 133             Rape (revised definition)
# 262  Murder and nonnegligent manslaughter
# 190                    Aggravated assault
# 5               Rape (revised definition)
# 211                    Aggravated assault
# 263  Murder and nonnegligent manslaughter
# 238             Rape (revised definition)
# 240  Murder and nonnegligent manslaughter
# 221                    Aggravated assault
# 210             Rape (revised definition)
# 279  Murder and nonnegligent manslaughter
# 273                    Aggravated assault
# 266             Rape (revised definition)
# 307                    Aggravated assault
# 291  Murder and nonnegligent manslaughter
# 295             Rape (revised definition)

# %%
# Non-violent crime categorization for NY starts here:
# create non-violent crimes list
nonVcrime = ["Motor vehicle theft", "Larceny", "Burglary", "Robbery", "Property crime"]

# restricting new DataFrame to non-violent crimes in above list:
CAcrimeRatesNonViolent = CAcrimeRates.loc[CAcrimeRates["crime_type"].isin(nonVcrime)]
CAcrimeRatesNonViolent = CAcrimeRatesNonViolent.drop_duplicates()
CAcrimeRatesNonViolentYears = CAcrimeRatesNonViolent.loc[CAcrimeRatesNonViolent["year"].isin(years)]

# drop extraneous columns
CAcrimeRatesNVComparison = CAcrimeRatesNonViolentYears.drop(columns=["key", "id", "place_name"])
# sort year in ascending order
CAcrimeRatesNVComparison = CAcrimeRatesNVComparison.sort_values(['year'], ascending=[True])

# Create seperate dataframes for each type of crime:
CAlarceny = CAcrimeRatesNVComparison.loc[CAcrimeRatesNVComparison["crime_type"] == "Larceny"]
# set the index of each dataframe to the year
CAlarceny = CAlarceny.set_index(["year"])

CAmotor = CAcrimeRatesNVComparison.loc[CAcrimeRatesNVComparison["crime_type"] == "Motor vehicle theft"]
CAmotor = CAmotor.set_index(["year"])

CAburglary = CAcrimeRatesNVComparison.loc[CAcrimeRatesNVComparison["crime_type"] == "Burglary"]
CAburglary = CAburglary.set_index(["year"])

CArobbery = CAcrimeRatesNVComparison.loc[CAcrimeRatesNVComparison["crime_type"] == "Robbery"]
CArobbery = CArobbery.set_index(["year"])

CApropCrime = CAcrimeRatesNVComparison.loc[CAcrimeRatesNVComparison["crime_type"] == "Property crime"]
CApropCrime = CApropCrime.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
CA_x_axis = CAlarceny.index
# each bar is a line here
p1 = plt.bar(CA_x_axis, CAlarceny["value"], color='purple', alpha=0.5, align="center")
p2 = plt.bar(CA_x_axis, CAmotor["value"].values, color='red', bottom=CAlarceny["value"].values)
p3 = plt.bar(CA_x_axis, CAburglary["value"].values, color='black', bottom=(CAmotor["value"] + CAlarceny["value"]).values)
p4 = plt.bar(CA_x_axis, CArobbery["value"].values, color="#ADD8E6", bottom = (CAmotor["value"] + CAlarceny["value"] + CAburglary["value"]).values)
p5 = plt.bar(CA_x_axis, CApropCrime["value"].values, color='pink', bottom = (CAmotor["value"] + CAlarceny["value"] + CAburglary["value"] + CArobbery["value"]).values)

tick_locations = [value for value in CA_x_axis]
plt.xticks(tick_locations, years)
plt.title("Riverside, CA Non-Violent Crime Rate: \n Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ("Larceny", "Motor-vehicle Theft", "Burglary", "Robbery", "Property Crime"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
CAcrimeRatesNVComparison
# Out:
#                       name   type variable        value  year  \
# 36   Riverside, California  place     rate  3198.041825  2009
# 135  Riverside, California  place     rate   673.622991  2009
# 67   Riverside, California  place     rate  2080.561308  2009
# 105  Riverside, California  place     rate   443.857525  2009
# 83   Riverside, California  place     rate   222.428978  2009
# 16   Riverside, California  place     rate   166.302810  2010
# 156  Riverside, California  place     rate  2131.458727  2010
# 145  Riverside, California  place     rate   685.088071  2010
# 60   Riverside, California  place     rate  3300.547607  2010
# 111  Riverside, California  place     rate   484.000808  2010
# 0    Riverside, California  place     rate  2042.004534  2011
# 181  Riverside, California  place     rate   676.548173  2011
# 124  Riverside, California  place     rate  3132.613200  2011
# 177  Riverside, California  place     rate   148.970704  2011
# 17   Riverside, California  place     rate   414.060493  2011
# 178  Riverside, California  place     rate   716.673258  2012
# 89   Riverside, California  place     rate  2262.926910  2012
# 68   Riverside, California  place     rate  3450.365513  2012
# 37   Riverside, California  place     rate   164.895449  2012
# 19   Riverside, California  place     rate   470.765345  2012
# 194  Riverside, California  place     rate   542.944097  2013
# 4    Riverside, California  place     rate  2184.417694  2013
# 172  Riverside, California  place     rate   156.436163  2013
# 104  Riverside, California  place     rate   625.112587  2013
# 78   Riverside, California  place     rate  3352.474378  2013
# 128  Riverside, California  place     rate   481.761010  2014
# 183  Riverside, California  place     rate  3087.778171  2014
# 186  Riverside, California  place     rate   479.256729  2014
# 77   Riverside, California  place     rate   138.048477  2014
# 169  Riverside, California  place     rate  2126.760431  2014
# 241  Riverside, California  place     rate   505.472600  2015
# 223  Riverside, California  place     rate  3259.725627  2015
# 198  Riverside, California  place     rate  2211.326548  2015
# 205  Riverside, California  place     rate   160.958819  2015
# 208  Riverside, California  place     rate   542.926479  2015
# 236  Riverside, California  place     rate  3456.931045  2016
# 229  Riverside, California  place     rate   593.440852  2016
# 203  Riverside, California  place     rate   606.635246  2016
# 204  Riverside, California  place     rate  2256.854948  2016
# 228  Riverside, California  place     rate   179.811965  2016
# 275  Riverside, California  place     rate   527.402042  2017
# 278  Riverside, California  place     rate  3058.322130  2017
# 280  Riverside, California  place     rate   510.025212  2017
# 283  Riverside, California  place     rate  2020.894876  2017
# 285  Riverside, California  place     rate   165.842029  2017
# 303  Riverside, California  place     rate   444.079245  2018
# 293  Riverside, California  place     rate   557.364767  2018
# 297  Riverside, California  place     rate   164.037436  2018
# 299  Riverside, California  place     rate  2087.776643  2018
# 305  Riverside, California  place     rate  3089.220656  2018
#
#               crime_type
# 36        Property crime
# 135             Burglary
# 67               Larceny
# 105  Motor vehicle theft
# 83               Robbery
# 16               Robbery
# 156              Larceny
# 145             Burglary
# 60        Property crime
# 111  Motor vehicle theft
# 0                Larceny
# 181             Burglary
# 124       Property crime
# 177              Robbery
# 17   Motor vehicle theft
# 178             Burglary
# 89               Larceny
# 68        Property crime
# 37               Robbery
# 19   Motor vehicle theft
# 194  Motor vehicle theft
# 4                Larceny
# 172              Robbery
# 104             Burglary
# 78        Property crime
# 128  Motor vehicle theft
# 183       Property crime
# 186             Burglary
# 77               Robbery
# 169              Larceny
# 241             Burglary
# 223       Property crime
# 198              Larceny
# 205              Robbery
# 208  Motor vehicle theft
# 236       Property crime
# 229  Motor vehicle theft
# 203             Burglary
# 204              Larceny
# 228              Robbery
# 275  Motor vehicle theft
# 278       Property crime
# 280             Burglary
# 283              Larceny
# 285              Robbery
# 303             Burglary
# 293  Motor vehicle theft
# 297              Robbery
# 299              Larceny
# 305       Property crime

# %%
# TX HAS NO 2014 DATA!
file_to_load3 = os.path.join("Output CSVs", "Fortworth.csv")
TXyears = [2009, 2010, 2011, 2012, 2013, 2015, 2016, 2017, 2018]

# load your city's CSV in a dataframe
TXcrimeDF = pd.read_csv(file_to_load3)

# filter whole NY dataset to just showing rates, not counts:
TXcrimeRates = TXcrimeDF.loc[TXcrimeDF["variable"] == "rate"]

# creating violent crime only set from there:
# restrict this violent crime set to a period of years useful for comparison w/ weed-legal cities:
TXcrimeRatesYears = TXcrimeRates.loc[TXcrimeRates["year"].isin(TXyears)]
TXcrimeRatesYears = TXcrimeRatesYears.drop_duplicates()
# remove extraneous columns
TXcrimeRatesYears = TXcrimeRatesYears.drop(columns=["key", "id", "place_name"])
# sort the years to print in ascending order
TXcrimeRatesYears = TXcrimeRatesYears.sort_values(['year'], ascending=[True])

# create a list with the text of each violent-crime category and filter data again
Vcrime = ["Forcible rape", "Murder and nonnegligent manslaughter", "Aggravated assault", "Rape (revised definition)"]
TXcrimeRatesViolent = TXcrimeRatesYears.loc[TXcrimeRatesYears["crime_type"].isin(Vcrime)]

# Create seperate dataframes for each type of crime:

# create another category for the rape-specific crime types
rapeCategories = ["Forcible rape", "Rape (revised definition)"]
TXrape = TXcrimeRatesViolent.loc[TXcrimeRatesViolent["crime_type"].isin(rapeCategories)]
# set the index of each dataframe to the year the data was from
TXrape = TXrape.set_index(["year"])

TXmurder = TXcrimeRatesViolent.loc[TXcrimeRatesViolent["crime_type"] == "Murder and nonnegligent manslaughter"]
TXmurder = TXmurder.set_index(["year"])

TXassault = TXcrimeRatesViolent.loc[TXcrimeRatesViolent["crime_type"] == "Aggravated assault"]
TXassault = TXassault.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
TX_x_axis = TXrape.index
# each bar is a line here
p1 = plt.bar(TX_x_axis, TXrape["value"], color='black', alpha=0.5, align="center")
# the bottom arguments indicate where to start the second, third, etc bar in the set. From 2 on they become sums:
p2 = plt.bar(TX_x_axis, TXmurder["value"].values, color='#AD1457', bottom=TXrape["value"].values)
p3 = plt.bar(TX_x_axis, TXassault["value"].values, color='#4527A0', bottom=(TXmurder["value"] + TXrape["value"]).values)

tick_locations = [value for value in TX_x_axis]
plt.xticks(tick_locations, TXyears)
plt.title("Fort Worth, TX Violent Crime Rate: \n Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0]), ("Rape", "Murder & Non-negligent Manslaughter", "Aggravated Assault"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
TXcrimeRatesViolent
# Out:
#                   name   type variable       value  year  \
# 50   Fort Worth, Texas  place     rate  327.455989  2009
# 158  Fort Worth, Texas  place     rate   51.143401  2009
# 138  Fort Worth, Texas  place     rate    6.081918  2009
# 77   Fort Worth, Texas  place     rate    8.440141  2010
# 127  Fort Worth, Texas  place     rate  345.911823  2010
# 116  Fort Worth, Texas  place     rate   42.602618  2010
# 21   Fort Worth, Texas  place     rate    6.342470  2011
# 157  Fort Worth, Texas  place     rate  383.719409  2011
# 140  Fort Worth, Texas  place     rate   46.247174  2011
# 6    Fort Worth, Texas  place     rate   50.772561  2012
# 96   Fort Worth, Texas  place     rate  364.757350  2012
# 7    Fort Worth, Texas  place     rate    5.713536  2012
# 27   Fort Worth, Texas  place     rate    6.083380  2013
# 59   Fort Worth, Texas  place     rate  328.629275  2013
# 144  Fort Worth, Texas  place     rate   66.283498  2013
# 224  Fort Worth, Texas  place     rate   62.188830  2015
# 190  Fort Worth, Texas  place     rate    6.749175  2015
# 195  Fort Worth, Texas  place     rate  338.181893  2015
# 215  Fort Worth, Texas  place     rate    7.747852  2016
# 197  Fort Worth, Texas  place     rate   58.578457  2016
# 204  Fort Worth, Texas  place     rate  323.179343  2016
# 254  Fort Worth, Texas  place     rate    8.017694  2017
# 250  Fort Worth, Texas  place     rate   65.172398  2017
# 249  Fort Worth, Texas  place     rate  339.721145  2017
# 285  Fort Worth, Texas  place     rate  316.193681  2018
# 269  Fort Worth, Texas  place     rate    6.489467  2018
# 273  Fort Worth, Texas  place     rate   53.929708  2018
#
#                                crime_type
# 50                     Aggravated assault
# 158                         Forcible rape
# 138  Murder and nonnegligent manslaughter
# 77   Murder and nonnegligent manslaughter
# 127                    Aggravated assault
# 116                         Forcible rape
# 21   Murder and nonnegligent manslaughter
# 157                    Aggravated assault
# 140                         Forcible rape
# 6                           Forcible rape
# 96                     Aggravated assault
# 7    Murder and nonnegligent manslaughter
# 27   Murder and nonnegligent manslaughter
# 59                     Aggravated assault
# 144             Rape (revised definition)
# 224             Rape (revised definition)
# 190  Murder and nonnegligent manslaughter
# 195                    Aggravated assault
# 215  Murder and nonnegligent manslaughter
# 197             Rape (revised definition)
# 204                    Aggravated assault
# 254  Murder and nonnegligent manslaughter
# 250             Rape (revised definition)
# 249                    Aggravated assault
# 285                    Aggravated assault
# 269  Murder and nonnegligent manslaughter
# 273             Rape (revised definition)

# %%
# Non-violent crime categorization for NY starts here:
# create non-violent crimes list
nonVcrime = ["Motor vehicle theft", "Larceny", "Burglary", "Robbery", "Property crime"]

# restricting new DataFrame to non-violent crimes in above list:
TXcrimeRatesNonViolent = TXcrimeRates.loc[TXcrimeRates["crime_type"].isin(nonVcrime)]
TXcrimeRatesNonViolent = TXcrimeRatesNonViolent.drop_duplicates()
TXcrimeRatesNonViolentYears = TXcrimeRatesNonViolent.loc[TXcrimeRatesNonViolent["year"].isin(TXyears)]

# drop extraneous columns
TXcrimeRatesNVComparison = TXcrimeRatesNonViolentYears.drop(columns=["key", "id", "place_name"])
# sort year in ascending order
TXcrimeRatesNVComparison = TXcrimeRatesNVComparison.sort_values(['year'], ascending=[True])

# Create seperate dataframes for each type of crime:
TXlarceny = TXcrimeRatesNVComparison.loc[TXcrimeRatesNVComparison["crime_type"] == "Larceny"]
# set the index of each dataframe to the year
TXlarceny = TXlarceny.set_index(["year"])

TXmotor = TXcrimeRatesNVComparison.loc[TXcrimeRatesNVComparison["crime_type"] == "Motor vehicle theft"]
TXmotor = TXmotor.set_index(["year"])

TXburglary = TXcrimeRatesNVComparison.loc[TXcrimeRatesNVComparison["crime_type"] == "Burglary"]
TXburglary = TXburglary.set_index(["year"])

TXrobbery = TXcrimeRatesNVComparison.loc[TXcrimeRatesNVComparison["crime_type"] == "Robbery"]
TXrobbery = TXrobbery.set_index(["year"])

TXpropCrime = TXcrimeRatesNVComparison.loc[TXcrimeRatesNVComparison["crime_type"] == "Property crime"]
TXpropCrime = TXpropCrime.set_index(["year"])

# Create a stacked bar plot where each crime type is in a distinct color:

# indices of each dataframe are the same size, can use arbitrary one for plot x-axis
TX_x_axis = TXlarceny.index
# each bar is a line here
p1 = plt.bar(TX_x_axis, TXlarceny["value"], color='purple', alpha=0.5, align="center")
p2 = plt.bar(TX_x_axis, TXmotor["value"].values, color='red', bottom=TXlarceny["value"].values)
p3 = plt.bar(TX_x_axis, TXburglary["value"].values, color='black', bottom=(TXmotor["value"] + TXlarceny["value"]).values)
p4 = plt.bar(TX_x_axis, TXrobbery["value"].values, color="#ADD8E6", bottom = (TXmotor["value"] + TXlarceny["value"] + TXburglary["value"]).values)
p5 = plt.bar(TX_x_axis, TXpropCrime["value"].values, color='pink', bottom = (TXmotor["value"] + TXlarceny["value"] + TXburglary["value"] + TXrobbery["value"]).values)

tick_locations = [value for value in TX_x_axis]
plt.xticks(tick_locations, TXyears)
plt.title("Fort Worth, TX Non-Violent Crime Rate: \n Pre- and Post-Marijuana Legalization Years")
plt.ylabel("Crime Rate (per 100,000 People)")
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ("Larceny", "Motor-vehicle Theft", "Burglary", "Robbery", "Property Crime"), bbox_to_anchor=(1.2, -0.11),
          fancybox=True, shadow=True, ncol=5)
TXcrimeRatesNVComparison
# Out:
#                   name   type variable        value  year           crime_type
# 143  Fort Worth, Texas  place     rate  3257.143489  2009              Larceny
# 24   Fort Worth, Texas  place     rate   200.288615  2009              Robbery
# 142  Fort Worth, Texas  place     rate   294.696568  2009  Motor vehicle theft
# 93   Fort Worth, Texas  place     rate  4960.080502  2009       Property crime
# 54   Fort Worth, Texas  place     rate  1408.240446  2009             Burglary
# 66   Fort Worth, Texas  place     rate   178.180761  2010              Robbery
# 133  Fort Worth, Texas  place     rate  1252.892088  2010             Burglary
# 160  Fort Worth, Texas  place     rate  4701.024740  2010       Property crime
# 173  Fort Worth, Texas  place     rate   330.103305  2010  Motor vehicle theft
# 153  Fort Worth, Texas  place     rate  3118.029348  2010              Larceny
# 60   Fort Worth, Texas  place     rate   322.673140  2011  Motor vehicle theft
# 51   Fort Worth, Texas  place     rate  2988.492382  2011              Larceny
# 94   Fort Worth, Texas  place     rate  4640.177166  2011       Property crime
# 42   Fort Worth, Texas  place     rate  1329.011645  2011             Burglary
# 171  Fort Worth, Texas  place     rate   167.414770  2011              Robbery
# 63   Fort Worth, Texas  place     rate   314.763908  2012  Motor vehicle theft
# 91   Fort Worth, Texas  place     rate  2811.059848  2012              Larceny
# 37   Fort Worth, Texas  place     rate  4222.043602  2012       Property crime
# 174  Fort Worth, Texas  place     rate   166.211964  2012              Robbery
# 145  Fort Worth, Texas  place     rate  1096.219846  2012             Burglary
# 10   Fort Worth, Texas  place     rate  4343.533557  2013       Property crime
# 85   Fort Worth, Texas  place     rate   304.042279  2013  Motor vehicle theft
# 83   Fort Worth, Texas  place     rate  2985.545635  2013              Larceny
# 19   Fort Worth, Texas  place     rate  1053.945642  2013             Burglary
# 152  Fort Worth, Texas  place     rate   159.181785  2013              Robbery
# 242  Fort Worth, Texas  place     rate   272.136391  2015  Motor vehicle theft
# 192  Fort Worth, Texas  place     rate  2589.875514  2015              Larceny
# 237  Fort Worth, Texas  place     rate   723.728534  2015             Burglary
# 226  Fort Worth, Texas  place     rate  3585.740439  2015       Property crime
# 207  Fort Worth, Texas  place     rate   118.231089  2015              Robbery
# 232  Fort Worth, Texas  place     rate  3301.524096  2016       Property crime
# 201  Fort Worth, Texas  place     rate   624.054263  2016             Burglary
# 199  Fort Worth, Texas  place     rate   280.096590  2016  Motor vehicle theft
# 198  Fort Worth, Texas  place     rate   136.761327  2016              Robbery
# 223  Fort Worth, Texas  place     rate  2397.373243  2016              Larceny
# 245  Fort Worth, Texas  place     rate   309.941139  2017  Motor vehicle theft
# 260  Fort Worth, Texas  place     rate  3215.324333  2017       Property crime
# 261  Fort Worth, Texas  place     rate  2319.404308  2017              Larceny
# 263  Fort Worth, Texas  place     rate   585.978886  2017             Burglary
# 265  Fort Worth, Texas  place     rate   147.296491  2017              Robbery
# 281  Fort Worth, Texas  place     rate   503.940673  2018             Burglary
# 271  Fort Worth, Texas  place     rate   332.529236  2018  Motor vehicle theft
# 275  Fort Worth, Texas  place     rate   124.866295  2018              Robbery
# 277  Fort Worth, Texas  place     rate  2009.161337  2018              Larceny
# 283  Fort Worth, Texas  place     rate  2845.631246  2018       Property crime
